# %% [markdown]
# <a href="https://colab.research.google.com/github/trailmarkerlib/policeProjectPythonWorkshop/blob/main/python_workshop_2024_01_31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ### Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Read in the data

# %%
url = 'https://raw.githubusercontent.com/trailmarkerlib/pythonWorkshop/main/data/e03a89dd-134a-4ee8-a2bd-62c40aeebc6f.csv'

# %%
df = pd.read_csv(url)
# Out:
# <ipython-input-4-7832ba498456>:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)

# %%
df = pd.read_csv(url, low_memory=False)

# %%
df.head()
# Out:
#    _id       PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0    1  1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1    2  1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2    3  1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3    4  1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4    5  1974596  16145962  25.0      M    B  2016-08-06T02:00:00
#
#                                      ARRESTLOCATION  \
# 0         4700 Block Centre AV Pittsburgh, PA 15213
# 1  4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2        900 Block Freeport RD Fox Chapel, PA 15238
# 3       Foreland ST & Cedar AV Pittsburgh, PA 15212
# 4         900 Block Woodlow ST Pittsburgh, PA 15205
#
#                                             OFFENSES  \
# 0                                 3929 Retail Theft.
# 1       13(a)(16) Possession of Controlled Substance
# 2                                 3929 Retail Theft.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65659 entries, 0 to 65658
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _id                    65659 non-null  int64
#  1   PK                     65659 non-null  int64
#  2   CCR                    65659 non-null  int64
#  3   AGE                    65256 non-null  float64
#  4   GENDER                 65659 non-null  object
#  5   RACE                   65659 non-null  object
#  6   ARRESTTIME             65659 non-null  object
#  7   ARRESTLOCATION         65659 non-null  object
#  8   OFFENSES               65656 non-null  object
#  9   INCIDENTLOCATION       65659 non-null  object
#  10  INCIDENTNEIGHBORHOOD   63199 non-null  object
#  11  INCIDENTZONE           65559 non-null  object
#  12  INCIDENTTRACT          63222 non-null  float64
#  13  COUNCIL_DISTRICT       55592 non-null  float64
# ...

# %%
df.isna()
# Out:
#          _id     PK    CCR    AGE  GENDER   RACE  ARRESTTIME  ARRESTLOCATION  \
# 0      False  False  False  False   False  False       False           False
# 1      False  False  False  False   False  False       False           False
# 2      False  False  False  False   False  False       False           False
# 3      False  False  False  False   False  False       False           False
# 4      False  False  False  False   False  False       False           False
# ...      ...    ...    ...    ...     ...    ...         ...             ...
# 65654  False  False  False  False   False  False       False           False
# 65655  False  False  False  False   False  False       False           False
# 65656  False  False  False  False   False  False       False           False
# 65657  False  False  False  False   False  False       False           False
# 65658  False  False  False  False   False  False       False           False
#
# ...

# %%
df.isna().sum()
# Out:
# _id                          0
# PK                           0
# CCR                          0
# AGE                        403
# GENDER                       0
# RACE                         0
# ARRESTTIME                   0
# ARRESTLOCATION               0
# OFFENSES                     3
# INCIDENTLOCATION             0
# INCIDENTNEIGHBORHOOD      2460
# INCIDENTZONE               100
# INCIDENTTRACT             2437
# COUNCIL_DISTRICT         10067
# PUBLIC_WORKS_DIVISION    10067
# X                         9052
# Y                         9052
# dtype: int64

# %%
df['OFFENSES'].head()
# Out:
# 0                                   3929 Retail Theft.
# 1         13(a)(16) Possession of Controlled Substance
# 2                                   3929 Retail Theft.
# 3    5503 Disorderly Conduct. / 5505 Public Drunken...
# 4    2702 Aggravated Assault. / 2705 Recklessy Enda...
# Name: OFFENSES, dtype: object

# %%
df.OFFENSES.head()
# Out:
# 0                                   3929 Retail Theft.
# 1         13(a)(16) Possession of Controlled Substance
# 2                                   3929 Retail Theft.
# 3    5503 Disorderly Conduct. / 5505 Public Drunken...
# 4    2702 Aggravated Assault. / 2705 Recklessy Enda...
# Name: OFFENSES, dtype: object

# %%
df.GENDER.unique()
# Out:
# array(['F', 'M', 'U'], dtype=object)

# %%
male_df = df.loc[df.GENDER == 'M'].copy()

# %%
male_df = df.loc[df['GENDER'] == 'M'].copy()

# %%
df['GENDER'] == 'M'
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 65654     True
# 65655     True
# 65656     True
# 65657    False
# 65658    False
# Name: GENDER, Length: 65659, dtype: bool

# %%
male_df['GENDER'].head()
# Out:
# 1    M
# 4    M
# 5    M
# 6    M
# 8    M
# Name: GENDER, dtype: object

# %%
new_df = df.loc[:,['PK', 'GENDER']].copy()

# %%
new_df.head()
# Out:
#         PK GENDER
# 0  1975272      F
# 1  1974456      M
# 2  1974466      F
# 3  1974550      F
# 4  1974596      M

# %%
df['RACE'].unique()
# Out:
# array(['B', 'W', 'H', 'O', 'U', 'A', 'I'], dtype=object)

# %%
bwh_df = df.loc[df['RACE'].isin(['B','W','H'])].copy()

# %%
bwh_df['RACE'].unique()
# Out:
# array(['B', 'W', 'H'], dtype=object)

# %%
df['OFFENSES'].unique()
# Out:
# array(['3929 Retail Theft.',
#        '13(a)(16) Possession of Controlled Substance',
#        '5503 Disorderly Conduct. / 5505 Public Drunkenness', ...,
#        '2706 Terroristic Threats. / 4952 Intimidation of Witnesses or Victims / 2709(b) Stalking / 2709(a)(3) Harassment No Legitimate Purpose',
#        '2701 Simple Assault. / 2705 Recklessy Endangering Another Person. / 6106 Firearms not to be Carried without a License.',
#        '3925 Receiving Stolen Property. / 3928 Unauthorized Use of Automobile and Other Vehicles. / 5126 Flight to Avoid Apprehension, Trial or Punishment. / 6106 Firearms not to be Carried without a License. / 1501 Drivers Required to be Licensed. / 6110.1 Possesion of Firearm by Minor / 3921(a) Theft by Unlawful Taking or Disposition - Movable item'],
#       dtype=object)

# %%
# comment
df['mari_flag'] = [1 if ('marijuana' in str(x).lower()) or ('paraphernalia' in str(x).lower()) else 0 for x in df['OFFENSES']]

# %%
df['mari_flag']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 65654    1
# 65655    0
# 65656    0
# 65657    0
# 65658    0
# Name: mari_flag, Length: 65659, dtype: int64

# %%
mari_df = df.loc[df['mari_flag'] == 1].copy()

# %%
mari_df.head(10)
# Out:
#     _id       PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 14   15  1975078  16157821  53.0      M    B  2016-08-22T22:09:00
# 16   17  1975138  16160913  22.0      F    W  2016-08-27T02:04:00
# 22   23  1975395  16162377  26.0      F    B  2016-08-29T11:20:00
# 33   34  1974767  16151393  32.0      M    W  2016-08-13T17:08:00
# 57   58  1974709  16149939  21.0      F    B  2016-08-11T18:12:00
# 73   74  1975020  16157206  23.0      M    B  2016-08-22T02:56:00
# 75   76  1975037  16157322   NaN      M    B  2016-08-22T16:40:00
# 81   82  1974760  16149328  30.0      M    W  2016-08-10T21:20:00
# 83   84  1974775  16151710  19.0      M    B  2016-08-14T02:15:00
# 88   89  1975536  16165979  32.0      M    W  2016-09-03T08:00:00
#
#                                        ARRESTLOCATION  \
# 14         400 Block Foreland ST Pittsburgh, PA 15212
# 16        Middle ST & Suismon ST Pittsburgh, PA 15212
# 22       600 Block Smithfield ST Pittsburgh, PA 15222
# ...

# %%
mari_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13169 entries, 14 to 65654
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _id                    13169 non-null  int64
#  1   PK                     13169 non-null  int64
#  2   CCR                    13169 non-null  int64
#  3   AGE                    13119 non-null  float64
#  4   GENDER                 13169 non-null  object
#  5   RACE                   13169 non-null  object
#  6   ARRESTTIME             13169 non-null  object
#  7   ARRESTLOCATION         13169 non-null  object
#  8   OFFENSES               13169 non-null  object
#  9   INCIDENTLOCATION       13169 non-null  object
#  10  INCIDENTNEIGHBORHOOD   12864 non-null  object
#  11  INCIDENTZONE           13156 non-null  object
#  12  INCIDENTTRACT          12872 non-null  float64
#  13  COUNCIL_DISTRICT       11473 non-null  float64
# ...

# %%
mari_df.isna().sum()
# Out:
# _id                         0
# PK                          0
# CCR                         0
# AGE                        50
# GENDER                      0
# RACE                        0
# ARRESTTIME                  0
# ARRESTLOCATION              0
# OFFENSES                    0
# INCIDENTLOCATION            0
# INCIDENTNEIGHBORHOOD      305
# INCIDENTZONE               13
# INCIDENTTRACT             297
# COUNCIL_DISTRICT         1696
# PUBLIC_WORKS_DIVISION    1696
# X                        1441
# Y                        1441
# mari_flag                   0
# dtype: int64

# %%
non_mari_df = df.loc[df['mari_flag'] == 0].copy()

# %%
non_mari_df.shape
# Out:
# (52490, 18)

# %%
non_mari_df.shape[0]
# Out:
# 52490

# %%
mari_df.shape[0] + non_mari_df.shape[0]
# Out:
# 65659

# %%
df.shape[0]
# Out:
# 65659

# %%
df.shape[1]
# Out:
# 18

# %%
mari_df.to_csv('/content/drive/MyDrive/_CAASI/Grief to Action - PDAP/marijuana.csv', index=False)
